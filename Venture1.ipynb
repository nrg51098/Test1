# %% [markdown]
# <a href="https://colab.research.google.com/github/nrg51098/Test1/blob/master/Venture1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas
import sqlalchemy

url = "https://openpaymentsdata.cms.gov/api/1/metastore/schemas/dataset/items?show-reference-ids=false"

# url = "http://api.coincap.io/v2/assets"
header = {"Content-Type":"application/json",
"Accept-Encoding":"deflate"}

response = requests.get(url, headers=header)
print(response)

responceData = response.json()
print(responceData)

df= pandas.json_normalize(responceData)
display(df)
# Out:
# <Response [200]>
# ...
